# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
bias_list = np.genfromtxt('bias.list', dtype=str)

# %%
print(bias_list)
# Out:
# ['AF702431.fits' 'AF702432.fits' 'AF702433.fits' 'AF702434.fits'
#  'AF702435.fits' 'AF702436.fits' 'AF702437.fits' 'AF702438.fits'
#  'AF702439.fits' 'AF702440.fits' 'AF702441.fits' 'AF702442.fits'
#  'AF702443.fits' 'AF702444.fits' 'AF702445.fits' 'AF702446.fits'
#  'AF702447.fits' 'AF702448.fits' 'AF702449.fits' 'AF702450.fits'
#  'AF702451.fits' 'AF702452.fits' 'AF702453.fits' 'AF702454.fits'
#  'AF702455.fits' 'AF702456.fits' 'AF702457.fits' 'AF702458.fits'
#  'AF702459.fits' 'AF702460.fits']

# %%
from astropy.io import fits

# %%
bias_fits = fits.open(bias_list[0])
print(bias_fits)
# Out:
# [<astropy.io.fits.hdu.image.PrimaryHDU object at 0x00000247D21721F0>]

# %%
bias_fits[0].header
# Out:
# SIMPLE  =                    T / file does conform to FITS standard
# BITPIX  =                   16 / number of bits per data pixel
# NAXIS   =                    2 / number of data axes
# NAXIS1  =                  521 / length of data axis 1
# NAXIS2  =                  132 / length of data axis 2
# EXTEND  =                    T / FITS dataset may contain extensions
# COMMENT   FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT   and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H
# BZERO   =                32768 / offset data range to that of unsigned short
# BSCALE  =                    1 / default scaling factor
# DATE    = '2021-09-10T01:51:10' / file creation date (YYYY-MM-DDThh:mm:ss UT)
# FILENAME= 'AF702431.fits'      / Original file name
# TIMESYS = 'UTC     '
# DATE-OBS= '2021-09-10T01:51:10.0' / UTC date at start of exposure
# JD      =       2459467.577200 / JD at start
# MJD     =         59467.077200 / MJD at start
# EXPTIME =                 0.00 / [s] Exposure time
# CCD-TEMP=                -95.5 / CCD temperature (Celsius) at start of exposure
# SET-TEMP=                -95.0 / CCD setpoint temperature (Celsius)
# IMAGETYP= 'Bias    '
# OBJECT  = 'bias wasp-135'
# OBSERVER= 'Borsato '
# PROGRAM = 'Nascimbeni'         / Program name
# FILTER  = 'r-Sloan '           / Filter Wheel position 6
# GRAT_TYP= 'NONE    '           / Grism Wheel position 1
# SLIT    = 'NONE    '           / Aperture Wheel position 1
# LAMP    = 'NO      '
# CAMERA  =                43609 / Actual Camera focus position
# FOCUSOFF=                -2980 / Filter focus offset
# ROTANGLE=                 -0.0 / [deg] Telescope flange rotation angle
# LTM1_1  =                0.250
# LTM2_2  =                0.250
# LTV1    =                   -1
# LTV2    =                 -509
# X-START =                    2 / physical windowing X start pixel
# Y-START =                  510 / physical windowing Y start pixel
# X-STOP  =                 2085 / physical windowing X stop pixel
# Y-STOP  =                 1037 / physical windowing Y stop pixel
# APPOS   =                    0 / Aperture wheel position
# FLPOS   =               200000 / Filter wheel position
# GRPOS   =                    0 / Grism wheel position
# ORIGIN  = 'Asiago Astronomical Observatory'
# TELESCOP= '1.82m Reflector'
# INSTRUME= 'AFOSC + Andor iKon-L DZ936N-BEX2-DD-9HF'
# DETECTOR= 'E2V CCD42-40 DD'
# BINX    =                    4 / Horizontal Binning factor used
# BINY    =                    4 / Vertical Binning factor used
# GAIN    =                 1.91 / [e/ADU] CCD Camera gain
# RDNOISE =                 7.10 / [e] CCD Camera readout noise
# CCDSCALE=                 0.25 / [arcsec/px] unbinned CCD camera scale
# SITETYPE= 'GEODETIC'
# SITESYS = 'WGS84   '
# SITELAT =           45.8485832 / [deg] Telescope latitude, N45:50:54.894
# SITELONG=           11.5689993 / [deg] Telescope longitude, E11:34:08.397
# SITEELEV=               1376.2 / [m] Telescope height above sea level
# HSSPEED =                    2 / 1 MHz CCD sensor horizontal shift speed
# OUTMODE =                    0 / High Sensitivity CCD sensor output mode
# PREAMP  =                    1 / x2 CCD sensor preamplifier gain
# HJD     =       2459467.581640 / Heliocentric Julian Date at middle of exposure
# EQUINOX =                2000.
# RADESYS = 'FK5     '
# LST     = '01:54:44.1'         / Local sideral time at start
# HA      = '+00:00:29'          / Telescope HA at start
# RA      = '01:53:08.09'        / Telescope RA (J2000.0)
# DEC     = '+00:00:48'          / Telescope DEC (J2000.0)
# ALTITUDE=             44.28645 / [deg] Telescope altitude at start
# AZIMUTH =              0.17047 / [deg] Telescope azimuth at start
# AIRMASS =                1.431 / Telescope airmass at start
# PARANGLE=                0.119 / [deg] Telescope parallactic angle at start
# URA     =             28.62074 / [deg] Telescope raw RA reading
# UDEC    =              0.12833 / [deg] Telescope raw Dec reading
# OBJCTNAM= 'Flat    '           / Object name from Telescope Control
# OBJCTRA = '01:48:51.61'        / Object RA (J2000.0)
# OBJCTDEC= '-00:06:30'          / Object DEC (J2000.0)
# M2-Z    =                7.199 / [mm] M2 Z (focus) position
# TEMP-M1E=                 15.9 / Main mirror est side temperature at start (Cels
# TEMP-M1W=                 14.9 / Main mirror west side temperature at start (Cel
# TEMP-M2 =                 13.8 / M2 mirror temperature at start (Celsius)
# TEMP-TOP=                 11.7 / Telescope Top Ring temperature at start (Celsiu
# TEMP-INT=                 13.0 / Dome temperature at start (Celsius)
# TEMP-EXT=                 12.9 / External temperature at start (Celsius)
# HUM-INT =                   54 / [%] Dome relative humidity at start
# HUM-EXT =                   67 / [%] External relative humidity at start
# TEMP-AF =                 16.1 / AFOSC temperature at start (Celsius)
# TEMP-FL =                 13.9 / Dome floor temperature at start (Celsius)
# TEMP-CEL=                 13.4 / Telescope Main mirror cell temperature at start
# WIND-DIR=                  101 / [deg] Wind Direction at start
# WIND-VEL=                  0.8 / [m/s] Wind Velocity at start

# %%
gain = bias_fits[0].header['GAIN']
airmass = bias_fits[0].header['AIRMASS']
readout_noise = bias_fits[0].header['RDNOISE']
print(gain, airmass, readout_noise)
# Out:
# 1.91 1.431 7.1

# %%
bias_fits[0].data
print(np.shape(bias_fits[0].data))
data = bias_fits[0].data * gain
# Out:
# (132, 521)

# %%
plt.figure(figsize=(9,4), tight_layout=True)
im = plt.imshow(data, cmap='viridis', interpolation='none', origin='lower')
plt.xlabel('X [pixels]')
plt.ylabel('Y [pixels]')
plt.colorbar(im, fraction=0.046, pad=0.04)
# Out:
# <img src="data:image/png;base64,..." width="1030.6908733475123">

# %%
n_image = len(bias_list)
x_shape, y_shape = np.shape(data)
print(n_image, x_shape, y_shape)
# Out:
# 30 132 521

# %%
stack = np.empty([n_image, x_shape, y_shape])

# %%
for i_bias, bias_name in enumerate(bias_list):
    bias_temp = fits.open(bias_name)
    stack[i_bias,:,:] = bias_temp[0].data * gain
    bias_temp.close()

# %%
print(stack)
# Out:
# [[[2779.05 2756.13 2784.78 ... 2765.68 2775.23 2775.23]
#   [2773.32 2763.77 2771.41 ... 2775.23 2759.95 2773.32]
#   [2780.96 2779.05 2767.59 ... 2779.05 2786.69 2773.32]
#   ...
#   [2761.86 2769.5  2773.32 ... 2784.78 2767.59 2771.41]
#   [2784.78 2763.77 2779.05 ... 2779.05 2773.32 2769.5 ]
#   [2779.05 2780.96 2765.68 ... 2775.23 2773.32 2773.32]]
#
#  [[2780.96 2744.67 2769.5  ... 2773.32 2786.69 2782.87]
#   [2782.87 2758.04 2792.42 ... 2773.32 2779.05 2779.05]
#   [2779.05 2767.59 2775.23 ... 2759.95 2784.78 2777.14]
#   ...
#   [2784.78 2777.14 2767.59 ... 2777.14 2794.33 2763.77]
#   [2779.05 2771.41 2775.23 ... 2773.32 2775.23 2773.32]
#   [2773.32 2769.5  2773.32 ... 2759.95 2775.23 2777.14]]
#
#  [[2782.87 2773.32 2792.42 ... 2779.05 2779.05 2771.41]
#   [2771.41 2765.68 2765.68 ... 2777.14 2782.87 2763.77]
#   [2771.41 2769.5  2779.05 ... 2786.69 2779.05 2780.96]
#   ...
#   [2777.14 2759.95 2779.05 ... 2771.41 2779.05 2784.78]
#   [2779.05 2773.32 2763.77 ... 2786.69 2782.87 2780.96]
#   [2775.23 2773.32 2779.05 ... 2775.23 2761.86 2765.68]]
#
#  ...
#
#  [[2763.77 2763.77 2788.6  ... 2773.32 2777.14 2777.14]
#   [2782.87 2771.41 2765.68 ... 2758.04 2775.23 2765.68]
#   [2771.41 2758.04 2777.14 ... 2782.87 2763.77 2775.23]
#   ...
#   [2780.96 2769.5  2771.41 ... 2773.32 2782.87 2784.78]
#   [2777.14 2756.13 2786.69 ... 2786.69 2780.96 2771.41]
#   [2775.23 2767.59 2773.32 ... 2777.14 2769.5  2773.32]]
#
#  [[2782.87 2777.14 2777.14 ... 2777.14 2767.59 2779.05]
#   [2773.32 2771.41 2771.41 ... 2773.32 2775.23 2792.42]
#   [2779.05 2752.31 2784.78 ... 2779.05 2786.69 2798.15]
#   ...
#   [2769.5  2771.41 2767.59 ... 2777.14 2777.14 2790.51]
#   [2777.14 2754.22 2775.23 ... 2777.14 2775.23 2784.78]
#   [2767.59 2765.68 2788.6  ... 2765.68 2779.05 2780.96]]
#
#  [[2780.96 2769.5  2777.14 ... 2779.05 2775.23 2782.87]
#   [2769.5  2771.41 2767.59 ... 2771.41 2771.41 2777.14]
#   [2771.41 2763.77 2780.96 ... 2759.95 2788.6  2800.06]
#   ...
#   [2775.23 2767.59 2784.78 ... 2792.42 2763.77 2784.78]
#   [2777.14 2771.41 2780.96 ... 2773.32 2775.23 2771.41]
#   [2777.14 2773.32 2771.41 ... 2780.96 2777.14 2784.78]]]

# %%
median_bias = np.median(stack, axis=0)
np.shape(median_bias)
# Out:
# (132, 521)

# %%
fig, ax = plt.subplots(2,1)
im1 = ax[0].imshow(data, vmin=2747, vmax=2812)
im2 = ax[1].imshow(median_bias, vmin=2747, vmax=2812)
fig.colorbar(im1, ax=ax)
# Out:
# <img src="data:image/png;base64,..." width="639.7090687245778">

# %%
print('STD of a single bias: ', np.std(data[:,100:500])) #in case of an overscan, skip the first 100 pixels on the left. 
print('readout noise: ', readout_noise)
print('expected STD of median bias: ', np.std(data[:,100:500])/np.sqrt(n_image))
print('expected noise of median bias: ', readout_noise/np.sqrt(n_image))
print('measured STD of median bias: ', np.std(median_bias[:,100:500]))
#In the unit of electrons.
# Out:
# STD of a single bias:  7.879237681458989
# readout noise:  7.1
# expected STD of median bias:  1.4385454046932642
# expected noise of median bias:  1.296276719428893
# measured STD of median bias:  1.8919885899451057

# %%
import pickle
pickle.dump(median_bias, open('median_bias.p', 'wb'))

# %%
favourite_median = pickle.load(open('median_bias.p', 'rb'))
print(favourite_median)
# Out:
# [[2776.185 2768.545 2776.185 ... 2777.14  2775.23  2775.23 ]
#  [2773.32  2767.59  2773.32  ... 2775.23  2775.23  2776.185]
#  [2776.185 2767.59  2775.23  ... 2776.185 2780.005 2777.14 ]
#  ...
#  [2776.185 2769.5   2773.32  ... 2776.185 2777.14  2777.14 ]
#  [2777.14  2767.59  2776.185 ... 2778.095 2777.14  2777.14 ]
#  [2775.23  2765.68  2777.14  ... 2775.23  2777.14  2777.14 ]]
